# %%
import csv
import pandas as pd
from bs4 import BeautifulSoup
import os
import requests

# %%
def check_link_status(url):
    try:
        page = requests.get(url)
        status_code = page.status_code
        if status_code==200:
            print (f'The Link {url} is accessible, Status ={status_code} OK')
            soup = BeautifulSoup(page.content, 'html.parser')
            return soup
        else: 
            print(f'The Link {url} is not accessible , Status = {status_code}')
    except ConnectionError:
        print(f'Failed to connect to {url}')

#Scraping the Page Title:
        
def get_book_title(soup):
    book_title_tags =soup.find_all('td', attrs={'class':'coll-1 name'})
    book_title=[]
    for tags in book_title_tags:
        book_title.append(tags.text.strip())
    return book_title

#Scrape the Movie Seeds:

def get_movie_seeds(soup):
    movie_seeds_tags=soup.find_all('td', attrs={'class':'coll-2 seeds'})
    movie_seeds=[]
    for tags in movie_seeds_tags:
        movie_seeds.append(tags.text.strip())
    return movie_seeds


#Iterating Through The Pages

def scrape_website(base_url, num_pages):
    all_titles = []
    all_seeds=[]
    urls = [f"{base_url}/search/death/{page}/" for page in range(1, num_pages + 10)]
    for url in urls:
        soup = check_link_status(url)
        print("Scraping This Page:", url)
       
        if soup:
            titles = get_book_title(soup)
            seeds = get_movie_seeds(soup)
        
            all_titles.extend(titles)
            all_seeds.extend(seeds)
          
    return all_titles  , all_seeds

if __name__ == "__main__":

    link_to_check = "https://www.1377x.to"
    check_link_status(link_to_check)

    base_url = "https://www.1377x.to"
    num_pages = 50
    all_titles, all_seeds = scrape_website(base_url, num_pages)
    
    
    df = pd.DataFrame({'Movie Title': all_titles, 'Movie Seeds': all_seeds})
    df.to_csv('1337x.csv', index=False)
# Out:
# The Link https://www.1377x.to is accessible, Status =200 OK
# The Link https://www.1377x.to/search/death/1/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/1/
# The Link https://www.1377x.to/search/death/2/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/2/
# The Link https://www.1377x.to/search/death/3/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/3/
# The Link https://www.1377x.to/search/death/4/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/4/
# The Link https://www.1377x.to/search/death/5/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/5/
# The Link https://www.1377x.to/search/death/6/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/6/
# The Link https://www.1377x.to/search/death/7/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/7/
# The Link https://www.1377x.to/search/death/8/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/8/
# The Link https://www.1377x.to/search/death/9/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/9/
# The Link https://www.1377x.to/search/death/10/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/10/
# The Link https://www.1377x.to/search/death/11/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/11/
# The Link https://www.1377x.to/search/death/12/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/12/
# The Link https://www.1377x.to/search/death/13/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/13/
# The Link https://www.1377x.to/search/death/14/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/14/
# The Link https://www.1377x.to/search/death/15/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/15/
# The Link https://www.1377x.to/search/death/16/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/16/
# The Link https://www.1377x.to/search/death/17/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/17/
# The Link https://www.1377x.to/search/death/18/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/18/
# The Link https://www.1377x.to/search/death/19/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/19/
# The Link https://www.1377x.to/search/death/20/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/20/
# The Link https://www.1377x.to/search/death/21/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/21/
# The Link https://www.1377x.to/search/death/22/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/22/
# The Link https://www.1377x.to/search/death/23/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/23/
# The Link https://www.1377x.to/search/death/24/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/24/
# The Link https://www.1377x.to/search/death/25/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/25/
# The Link https://www.1377x.to/search/death/26/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/26/
# The Link https://www.1377x.to/search/death/27/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/27/
# The Link https://www.1377x.to/search/death/28/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/28/
# The Link https://www.1377x.to/search/death/29/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/29/
# The Link https://www.1377x.to/search/death/30/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/30/
# The Link https://www.1377x.to/search/death/31/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/31/
# The Link https://www.1377x.to/search/death/32/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/32/
# The Link https://www.1377x.to/search/death/33/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/33/
# The Link https://www.1377x.to/search/death/34/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/34/
# The Link https://www.1377x.to/search/death/35/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/35/
# The Link https://www.1377x.to/search/death/36/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/36/
# The Link https://www.1377x.to/search/death/37/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/37/
# The Link https://www.1377x.to/search/death/38/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/38/
# The Link https://www.1377x.to/search/death/39/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/39/
# The Link https://www.1377x.to/search/death/40/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/40/
# The Link https://www.1377x.to/search/death/41/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/41/
# The Link https://www.1377x.to/search/death/42/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/42/
# The Link https://www.1377x.to/search/death/43/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/43/
# The Link https://www.1377x.to/search/death/44/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/44/
# The Link https://www.1377x.to/search/death/45/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/45/
# The Link https://www.1377x.to/search/death/46/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/46/
# The Link https://www.1377x.to/search/death/47/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/47/
# The Link https://www.1377x.to/search/death/48/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/48/
# The Link https://www.1377x.to/search/death/49/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/49/
# The Link https://www.1377x.to/search/death/50/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/50/
# The Link https://www.1377x.to/search/death/51/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/51/
# The Link https://www.1377x.to/search/death/52/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/52/
# The Link https://www.1377x.to/search/death/53/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/53/
# The Link https://www.1377x.to/search/death/54/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/54/
# The Link https://www.1377x.to/search/death/55/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/55/
# The Link https://www.1377x.to/search/death/56/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/56/
# The Link https://www.1377x.to/search/death/57/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/57/
# The Link https://www.1377x.to/search/death/58/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/58/
# The Link https://www.1377x.to/search/death/59/ is accessible, Status =200 OK
# Scraping This Page: https://www.1377x.to/search/death/59/
